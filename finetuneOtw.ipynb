# %% [markdown]
# <a href="https://colab.research.google.com/github/YobelAK/Lib/blob/main/finetuneOtw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn import tree

# %%
# Load and preprocess data
df = pd.read_csv('/dataset.csv')
df.columns = ["input","output"]

# %%
df
# Out:
#                   input  output
# 0                ndbypy       6
# 1       ytkdcqdvcdrnspa      15
# 2   qhkfflhumblxyizdtqs      19
# 3             otvzjwpwu       9
# 4                  zznl       4
# ..                  ...     ...
# 95                   ff       2
# 96        scjfnngmlgwav      13
# 97         cyanmqufpyce      12
# 98  nxztefgblcbddlqwbmw      19
# 99           xvarxiixhl      10
#
# [100 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# input     0
# output    0
# dtype: int64

# %%
fig, ax = plt.subplots()

# Create bar plot of first 1000 data entries
ax.bar(df["input"][:1000], df["output"][:1000], color="peru")

#Add legend: x is horizonatal axis, y is vertical
ax.set(title="input and Nr. of output",
       xlabel="input",
       ylabel="Number of output");

# %%
from sklearn.metrics import accuracy_score

# API key dan URL endpoint
API_KEY = "AIzaSyBThylHj5rH8KGKRBQNcQ8v2oPHJoiLRjc"
API_URL = "https://api-url-endpoint.com/predict"

# Fungsi untuk mengirim input ke API dan menerima prediksi
def get_predictions(input_data):
    headers = {
        'Authorization': f'Bearer {API_KEY}',
        'Content-Type': 'application/json'
    }
    response = requests.post(API_URL, headers=headers, data=json.dumps(input_data))

    if response.status_code == 200:
        return response.json()['predictions']  # Sesuaikan key sesuai dengan format respons API Anda
    else:
        raise Exception(f"Error: {response.status_code}, {response.text}")

# Contoh input data (X_test) dan label sebenarnya (y_true)
X_test = [
    # Masukkan input dataset yang ingin diuji di sini
    {"feature1": 1.0, "feature2": 2.0, "feature3": 3.0},
    {"feature1": 4.0, "feature2": 5.0, "feature3": 6.0},
    # Tambahkan lebih banyak data
]

y_true = [0, 1]  # Label sebenarnya dari X_test (harus sesuai panjang dengan X_test)

# Dapatkan prediksi dari model AI via API
try:
    predictions = get_predictions(X_test)
    # Hitung akurasi
    accuracy = accuracy_score(y_true, predictions)
    print(f"Akurasi model: {accuracy * 100:.2f}%")
except Exception as e:
    print(str(e))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b53ec804fdbd> in <cell line: 8>()
#       7 # Check if the API key is set
#       8 if api_key is None:
# ----> 9     raise ValueError("GOOGLE_API_KEY environment variable is not set.")
#      10
#      11 # Configure Google Generative AI
#
# ValueError: GOOGLE_API_KEY environment variable is not set.
